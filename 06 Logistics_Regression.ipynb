# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sympy.stats import Logistic

# %%
df = pd.read_csv('data/insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df['age'], df['bought_insurance'])
plt.xlabel('age')
plt.ylabel('bought_insurance')
# Out:
# Text(0, 0.5, 'bought_insurance')

# %%
x = df[['age']]
y = df['bought_insurance']
x_test,x_train,y_test,y_train = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#     age
# 25   54
# 2    47
# 16   25
# 13   29
# 12   27
# 24   50

# %%
model=linear_model.LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict_proba(x_test)
# Out:
# array([[0.06726696, 0.93273304],
#        [0.01342477, 0.98657523],
#        [0.00497793, 0.99502207],
#        [0.59203615, 0.40796385],
#        [0.00965406, 0.99034594],
#        [0.00587602, 0.99412398],
#        [0.01582256, 0.98417744],
#        [0.86684064, 0.13315936],
#        [0.76963179, 0.23036821],
#        [0.88494115, 0.11505885],
#        [0.82343142, 0.17656858],
#        [0.79786475, 0.20213525],
#        [0.16398977, 0.83601023],
#        [0.88494115, 0.11505885],
#        [0.01582256, 0.98417744],
#        [0.00693501, 0.99306499],
#        [0.6695005 , 0.3304995 ],
#        [0.04189639, 0.95810361],
#        [0.07851615, 0.92148385],
#        [0.02582966, 0.97417034],
#        [0.70530629, 0.29469371]])

# %%
model.predict_proba([[33]])
# Out:
# C:\Users\syeda\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[0.38664071, 0.61335929]])
